# %%
def sadiq_anju(a, b, c):
    return a+b+c

sadiq_anju(10, 15, 25)
# Out:
# 50

# %%
my_tuple = ("apple", "mango", 2, 54, "apple")
my_tuple.count("apple")
# my_tuple.index("apple")
# Out:
# 2

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

for x, my_detail in myfamily.items():
        
    for y in my_detail:
        print(y)
        print(y + ':', my_detail[y])
# Out:
# name
# name: Emil
# year
# year: 2004
# name
# name: Tobias
# year
# year: 2007
# name
# name: Linus
# year
# year: 2011

# %%
print(str(38.20))
# Out:
# 38.2

# %%
5 % 2
# Out:
# 1
