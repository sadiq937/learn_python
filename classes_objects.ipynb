# %%
class Anju:
    def __init__(self, name, age, sex, height):
        self.name = name
        self.age = age
        self.sex = sex
        self.height = height  
    def __str__(self):
        return f"my name is {self.name}, i am {self.age} years old, {self.sex} with height {self.height}cms"

S1 = Anju("anju", 29, "female", 172)
print(S1)
# Out:
# my name is anju, i am 29 years old, female with height 172cms

# %%
class Sadiq:
    def __init__(x,name,age,year,height,weight,name2):
        x.name = name
        x.age = age
        x.year = year
        x.height = height
        x.weight = weight
        x.name2 = "Geetanjali"
    def __str__(x):
        return f"My name is {x.name}, {x.age}years old, born in {x.year}. My height is {x.height}cms weighing {x.weight}kgs, my wife is {x.name2}"
a1 = Sadiq("SadiqSM", 29, 1995, 178, 94, "jss")
a1.age = 30
del a1
print(a1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 14
#      12 a1.age = 30
#      13 del a1
# ---> 14 print(a1)
#
# NameError: name 'a1' is not defined
